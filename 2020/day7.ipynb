# %%
s = "light red bags contain 1 bright white bag, 2 muted yellow bags."

def split_bag_expr(bag_expr):
    bag_expr = bag_expr.strip()
    num = bag_expr[0]
    colour = bag_expr[1:].split('bag')[0].strip()
    return num, colour

bags = {}

with open('inputs/day7', 'r') as f:
    for line in f:
        line = line.replace('.','')
        lhs, rhs = line.split('contain')[0].strip(), line.split('contain')[1].strip()
        colour = lhs.split('bags')[0].strip()

        if (rhs == "no other bags"):
            succs = None
        else:
            succs = {}

            successors = rhs.split(',')
            for succ in successors:
                num, col = split_bag_expr(succ)
                succs[col] = num     

        bags[colour] = succs

for k,v in bags.items():
    print(k, v)
# Out:
#  brown {'mirrored lavender': '5', 'dark chartreuse': '2'}
# pale chartreuse {'dotted gray': '4', 'pale purple': '1', 'muted silver': '5'}
# mirrored coral {'wavy purple': '3', 'dull blue': '3', 'drab magenta': '2', 'dotted chartreuse': '4'}
# drab olive {'posh green': '1'}
# dim purple {'dotted aqua': '5', 'pale gray': '3'}
# faded olive {'vibrant blue': '4', 'vibrant olive': '3', 'clear coral': '3', 'light tan': '5'}
# wavy purple {'wavy black': '3', 'dark indigo': '5', 'dotted violet': '4'}
# vibrant olive None
# dull indigo {'posh beige': '2'}
# dark purple {'bright coral': '2', 'faded lavender': '2'}
# pale violet {'posh bronze': '1', 'light beige': '1', 'dim teal': '1'}
# muted orange {'shiny cyan': '3', 'pale plum': '4'}
# dotted gray {'dark indigo': '5'}
# vibrant teal {'vibrant cyan': '4', 'mirrored gray': '2', 'striped salmon': '5', 'vibrant orange': '2'}
# light red {'dull lavender': '4', 'wavy purple': '4', 'mirrored coral': '1', 'muted crimson': '4'}
# shiny chartreuse {'dull olive': '3'}
# mirrored beige {'wavy tan': '4', 'faded tan': '4'}
# light indigo {'posh beige': '4', 'dull lavender': '4'}
# faded plum {'dotted lime': '2', 'dotted chartreuse': '3'}
# dim chartreuse {'vibrant plum': '2', 'dark indigo': '4'}
# bright white {'pale cyan': '1', 'dim yellow': '2', 'dark aqua': '3', 'plaid tan': '2'}
# muted turquoise {'bright silver': '3', 'dotted yellow': '2', 'clear tan': '1'}
# dull purple {'posh beige': '5', 'dim lavender': '5', 'vibrant violet': '5', 'bright lime': '5'}
# muted cyan {'vibrant violet': '4', 'muted salmon': '5', 'clear tan': '4'}
# dim blue {'muted salmon': '3'}
# wavy cyan {'vibrant red': '1', 'dim tomato': '2'}
# shiny red {'striped white': '4', 'light cyan': '1', 'drab blue': '2'}
# bright crimson {'striped turquoise': '5'}
# shiny magenta {'dull turquoise': '2', 'wavy yellow': '2'}
# dotted orange {'posh tan': '4', 'clear plum': '2'}
# dotted brown {'light magenta': '5', 'shiny lavender': '5'}
# bright tan {'shiny gold': '5', 'vibrant gray': '5', 'mirrored coral': '2'}
# dim olive {'bright black': '1'}
# striped yellow {'dark indigo': '5'}
# dull orange {'clear chartreuse': '2', 'wavy white': '1', 'dim coral': '5'}
# faded white {'posh teal': '1'}
# pale gold {'clear blue': '2'}
# faded orange {'shiny blue': '3', 'shiny turquoise': '5', 'posh turquoise': '2'}
# drab brown {'plaid olive': '3', 'plaid cyan': '5', 'pale coral': '4'}
# light white {'mirrored gray': '5', 'dim chartreuse': '2', 'posh lavender': '1', 'vibrant crimson': '5'}
# drab red {'bright purple': '5', 'wavy blue': '1', 'shiny magenta': '4'}
# muted coral {'dim tomato': '2', 'vibrant crimson': '1', 'faded magenta': '5', 'clear teal': '5'}
# plaid maroon {'striped tomato': '5'}
# drab black {'pale indigo': '2', 'muted lime': '1'}
# pale green {'vibrant white': '3'}
# wavy gray {'pale cyan': '3', 'vibrant lavender': '2'}
# clear gold {'muted plum': '3', 'clear cyan': '4', 'dull plum': '3', 'pale aqua': '3'}
# pale gray {'vibrant white': '5', 'plaid lavender': '1'}
# drab plum {'pale green': '1', 'wavy purple': '1', 'muted tan': '3', 'drab magenta': '2'}
# dotted fuchsia {'clear beige': '5', 'shiny blue': '3', 'clear red': '5', 'plaid olive': '3'}
# bright plum {'muted black': '4'}
# posh orange {'dotted black': '1', 'dotted cyan': '3'}
# dim fuchsia {'drab purple': '1'}
# dim plum {'vibrant gray': '4', 'plaid blue': '4', 'posh black': '5', 'dim cyan': '5'}
# muted purple {'shiny purple': '5', 'dim magenta': '2'}
# wavy olive {'plaid bronze': '5', 'wavy purple': '2', 'dark aqua': '2'}
# pale plum {'posh purple': '5'}
# dull brown {'dim blue': '4', 'dull gray': '5'}
# dark blue {'drab brown': '1', 'vibrant maroon': '1', 'dotted blue': '5', 'dim teal': '3'}
# striped bronze {'clear salmon': '2', 'posh bronze': '1', 'pale turquoise': '3', 'shiny green': '5'}
# drab maroon {'pale aqua': '4'}
# pale lavender {'dark green': '3', 'clear violet': '1', 'striped turquoise': '3'}
# light blue {'muted brown': '5', 'plaid indigo': '5', 'wavy purple': '3', 'dark chartreuse': '3'}
# light violet {'dark turquoise': '4'}
# pale purple {'dim red': '1', 'clear cyan': '2', 'posh lavender': '3', 'muted tomato': '5'}
# shiny violet {'dull blue': '4', 'light gold': '1', 'shiny gold': '4', 'posh teal': '5'}
# shiny bronze {'light tan': '1', 'faded fuchsia': '2', 'dull aqua': '3', 'clear coral': '2'}
# dotted yellow {'clear coral': '1', 'light magenta': '2', 'striped tomato': '4'}
# dim yellow {'muted gray': '5', 'mirrored lavender': '3'}
# dim white {'muted tan': '2', 'muted black': '2', 'pale beige': '4', 'dull bronze': '1'}
# clear tomato {'clear teal': '3'}
# clear crimson {'dotted chartreuse': '1'}
# striped red {'muted beige': '1', 'bright gray': '3', 'vibrant gray': '1', 'light coral': '3'}
# muted plum {'light gold': '2', 'striped turquoise': '1'}
# posh white {'dull olive': '3'}
# dim salmon {'faded fuchsia': '2', 'dim cyan': '2'}
# muted magenta {'posh cyan': '2', 'clear lavender': '2', 'wavy plum': '3'}
# dark aqua {'clear tan': '4', 'shiny purple': '4'}
# dim black {'dim orange': '1', 'plaid tan': '3', 'dotted purple': '2', 'dim teal': '1'}
# vibrant indigo {'shiny violet': '4', 'light blue': '5', 'faded purple': '1'}
# plaid black {'muted cyan': '3'}
# striped black {'vibrant violet': '5', 'muted tan': '4'}
# dotted turquoise {'clear orange': '2', 'muted plum': '5'}
# wavy fuchsia {'dull gold': '1'}
# wavy black {'dotted chartreuse': '3', 'clear coral': '3'}
# clear silver {'vibrant beige': '5', 'plaid bronze': '5', 'vibrant brown': '5'}
# wavy crimson {'plaid turquoise': '1'}
# clear orange {'posh teal': '5', 'bright green': '5'}
# light silver {'plaid tomato': '2', 'plaid plum': '1', 'dark yellow': '5'}
# pale black {'shiny lavender': '3', 'shiny olive': '5', 'light plum': '4', 'drab gray': '5'}
# striped coral {'posh gray': '1', 'clear crimson': '3', 'dotted violet': '3', 'shiny plum': '5'}
# clear violet {'dull magenta': '2'}
# clear bronze {'vibrant indigo': '2', 'drab plum': '3', 'striped lime': '3', 'striped olive': '2'}
# vibrant purple {'clear green': '1'}
# plaid yellow {'vibrant white': '4'}
# faded aqua {'clear yellow': '2', 'mirrored lavender': '1', 'light beige': '3', 'mirrored maroon': '2'}
# shiny teal {'posh cyan': '1', 'dull plum': '2', 'plaid olive': '5', 'drab teal': '2'}
# light brown {'wavy black': '4'}
# bright gray {'striped olive': '5', 'clear gray': '3'}
# plaid violet {'wavy black': '3', 'clear cyan': '1', 'dotted chartreuse': '5'}
# dark crimson {'dotted aqua': '1', 'drab plum': '2'}
# pale beige {'wavy black': '4', 'vibrant gray': '2', 'light tan': '5', 'mirrored coral': '5'}
# faded blue {'dim blue': '2', 'dotted coral': '2'}
# dotted red {'wavy gold': '2', 'dark silver': '1', 'vibrant lavender': '5', 'dim magenta': '5'}
# dotted blue {'dark gray': '3', 'muted lime': '5', 'vibrant crimson': '3'}
# plaid aqua {'posh brown': '5', 'vibrant gray': '2'}
# bright maroon {'dotted aqua': '2'}
# faded coral {'muted orange': '2', 'clear lavender': '5', 'faded magenta': '4'}
# dull plum {'dim white': '4'}
# clear coral None
# light purple {'striped violet': '1'}
# dotted white {'dim chartreuse': '2', 'wavy blue': '1', 'dull white': '1', 'vibrant indigo': '1'}
# faded bronze {'pale beige': '5', 'wavy blue': '1'}
# posh tomato {'dotted salmon': '1', 'pale brown': '2'}
# faded fuchsia {'vibrant olive': '3', 'dull blue': '1', 'dull aqua': '5'}
# muted fuchsia {'dotted yellow': '5', 'plaid tan': '4', 'pale crimson': '4'}
# shiny brown {'posh turquoise': '3', 'wavy yellow': '5'}
# clear gray {'faded olive': '1'}
# pale indigo {'dull lavender': '3', 'vibrant plum': '2'}
# plaid purple {'muted lime': '4', 'dotted chartreuse': '5', 'dotted violet': '2', 'light indigo': '5'}
# pale coral {'muted crimson': '4', 'vibrant black': '3', 'clear tan': '4'}
# dotted salmon {'vibrant red': '1'}
# muted gray {'mirrored turquoise': '3'}
# dotted indigo {'posh yellow': '1', 'dotted blue': '5', 'faded blue': '2'}
# mirrored orange {'posh beige': '2', 'posh chartreuse': '2'}
# dim tomato {'posh chartreuse': '5', 'striped yellow': '3', 'muted tomato': '3'}
# drab beige {'vibrant white': '1'}
# dull olive {'mirrored fuchsia': '4', 'faded lavender': '3'}
# shiny tan {'clear yellow': '2', 'wavy aqua': '3', 'pale plum': '1'}
# faded green {'dotted salmon': '1'}
# shiny black {'dotted lavender': '5'}
# dull yellow {'posh beige': '3', 'pale lavender': '1', 'wavy tan': '3', 'dark lavender': '3'}
# dull coral {'dark chartreuse': '2', 'striped tomato': '1'}
# striped plum {'dark maroon': '2'}
# mirrored brown {'pale crimson': '2', 'dim tomato': '1', 'bright black': '1'}
# clear purple {'clear tan': '4', 'light cyan': '4'}
# muted chartreuse {'pale crimson': '2', 'bright purple': '4'}
# clear olive {'muted silver': '4'}
# plaid olive {'vibrant olive': '5', 'dark gray': '2', 'pale cyan': '2'}
# bright teal {'clear gold': '1'}
# dim coral {'shiny turquoise': '2', 'mirrored white': '4', 'striped white': '3'}
# dotted teal {'light plum': '4'}
# bright brown {'wavy teal': '3', 'light beige': '3', 'mirrored indigo': '4', 'plaid lime': '5'}
# mirrored gold {'shiny magenta': '4', 'vibrant magenta': '1'}
# dotted plum {'bright orange': '5', 'light black': '4', 'shiny brown': '2'}
# vibrant silver {'dim chartreuse': '2', 'plaid brown': '1', 'bright chartreuse': '4'}
# dark olive {'clear beige': '4', 'dotted violet': '5', 'dim white': '3', 'pale crimson': '1'}
# dark coral {'light salmon': '4', 'shiny coral': '1', 'faded tomato': '3'}
# faded silver {'shiny magenta': '2'}
# shiny lime {'pale plum': '2', 'dim maroon': '4', 'faded lime': '2'}
# plaid brown {'vibrant blue': '4', 'vibrant white': '2', 'plaid gray': '5'}
# mirrored maroon {'dotted green': '3'}
# vibrant beige {'pale beige': '5', 'mirrored white': '1', 'mirrored lavender': '4'}
# faded brown {'drab indigo': '3', 'posh yellow': '1', 'clear yellow': '3'}
# drab aqua {'vibrant brown': '4', 'pale salmon': '5', 'vibrant violet': '1', 'dotted aqua': '2'}
# dim green {'light orange': '1', 'mirrored orange': '1'}
# dull maroon {'muted blue': '4', 'posh red': '5'}
# light olive {'vibrant violet': '2'}
# vibrant gold {'posh purple': '2', 'dotted black': '3', 'muted maroon': '1'}
# faded violet {'clear white': '2'}
# bright bronze {'striped bronze': '2', 'bright black': '3', 'vibrant plum': '3'}
# dark fuchsia {'dull coral': '2', 'shiny brown': '1'}
# dark teal {'clear yellow': '2', 'posh tan': '2', 'plaid indigo': '3', 'faded salmon': '3'}
# striped teal {'striped brown': '4'}
# faded turquoise {'shiny olive': '2'}
# dim beige {'shiny crimson': '1', 'clear green': '1', 'pale indigo': '3'}
# shiny white {'dull blue': '2', 'light aqua': '2'}
# wavy beige {'dark silver': '2', 'muted gray': '4'}
# light turquoise {'dim teal': '4', 'striped olive': '2'}
# bright lavender {'light lime': '1', 'faded blue': '2', 'dotted silver': '4', 'vibrant gold': '3'}
# pale tomato {'striped olive': '1'}
# clear tan {'plaid salmon': '5', 'posh maroon': '5', 'pale crimson': '2'}
# drab gray {'posh bronze': '4', 'muted red': '1'}
# striped white {'posh turquoise': '5', 'posh maroon': '2', 'vibrant black': '3'}
# drab tan {'drab olive': '2', 'bright black': '4', 'shiny coral': '2'}
# dull lime {'dim silver': '5', 'muted orange': '1', 'dark indigo': '4', 'posh coral': '2'}
# dull gold {'dim maroon': '2'}
# shiny beige {'dull purple': '5', 'striped chartreuse': '4'}
# faded cyan {'clear tan': '2', 'shiny coral': '4', 'drab olive': '1', 'wavy gold': '3'}
# dim brown {'pale coral': '5', 'posh turquoise': '5', 'striped lime': '4'}
# drab teal {'shiny tomato': '2', 'drab tomato': '4'}
# muted tan {'clear gray': '3'}
# shiny olive {'dull white': '3', 'faded chartreuse': '3'}
# bright cyan {'pale tan': '5', 'mirrored plum': '3', 'vibrant green': '1'}
# striped salmon {'plaid indigo': '1', 'dark chartreuse': '1'}
# pale lime {'pale yellow': '3', 'muted olive': '1', 'dull indigo': '4', 'light magenta': '2'}
# muted bronze {'dark olive': '5', 'faded lime': '2'}
# drab violet {'shiny cyan': '3', 'faded gray': '4'}
# light lime {'pale crimson': '2', 'mirrored red': '5'}
# dark salmon {'dim yellow': '5', 'mirrored red': '3', 'light gold': '4'}
# posh gray {'muted tomato': '4', 'bright black': '1', 'mirrored turquoise': '1', 'faded lavender': '1'}
# dull black {'drab olive': '4', 'vibrant fuchsia': '2', 'mirrored maroon': '3'}
# wavy yellow {'vibrant olive': '2'}
# light aqua {'shiny violet': '2'}
# faded salmon {'faded olive': '3', 'pale crimson': '2'}
# dull green {'bright orange': '3'}
# mirrored white {'clear black': '3'}
# drab silver {'dull magenta': '3'}
# faded maroon {'mirrored chartreuse': '1', 'drab white': '2', 'striped purple': '5'}
# dark yellow {'dotted fuchsia': '4'}
# posh maroon {'faded fuchsia': '4', 'vibrant olive': '3', 'dull aqua': '5'}
# vibrant orange {'muted gray': '3', 'striped gray': '1'}
# plaid blue {'dark purple': '3', 'muted white': '3', 'drab lavender': '4'}
# mirrored salmon {'light magenta': '1'}
# plaid fuchsia {'plaid brown': '2'}
# wavy orange {'dim brown': '1', 'dotted aqua': '5', 'striped black': '2'}
# mirrored cyan {'light chartreuse': '3', 'dotted maroon': '2', 'muted red': '5', 'light tan': '4'}
# mirrored red {'wavy turquoise': '2', 'striped tomato': '4', 'light red': '5', 'posh purple': '4'}
# shiny orange {'plaid gray': '2', 'drab beige': '1', 'plaid red': '2'}
# vibrant white {'light tan': '5', 'wavy black': '3', 'mirrored lavender': '2'}
# drab blue {'dark purple': '1'}
# dark gold {'dim white': '1', 'posh teal': '5'}
# mirrored gray {'bright olive': '1'}
# plaid white {'striped orange': '4', 'muted beige': '2', 'vibrant fuchsia': '2', 'plaid salmon': '4'}
# muted yellow {'striped bronze': '3', 'dull bronze': '4', 'dim crimson': '1', 'posh crimson': '5'}
# shiny yellow {'vibrant indigo': '2'}
# mirrored teal {'pale crimson': '5'}
# muted white {'shiny lavender': '5', 'dotted yellow': '4', 'dotted gray': '5'}
# posh green {'mirrored fuchsia': '2'}
# plaid salmon {'dull blue': '2', 'vibrant crimson': '2', 'drab magenta': '1', 'plaid silver': '5'}
# shiny tomato {'vibrant plum': '5', 'light blue': '5', 'striped magenta': '5'}
# drab magenta {'clear yellow': '4'}
# dim crimson {'dark beige': '1', 'posh tomato': '2'}
# faded tan {'posh fuchsia': '4'}
# dotted olive {'striped turquoise': '4', 'muted lavender': '1', 'dotted aqua': '5', 'wavy purple': '1'}
# dull magenta {'vibrant indigo': '4', 'mirrored salmon': '4', 'pale cyan': '2', 'muted salmon': '3'}
# muted violet {'faded olive': '2', 'posh green': '2'}
# wavy tan {'faded fuchsia': '1', 'plaid lime': '4', 'pale magenta': '1', 'dim yellow': '3'}
# vibrant yellow {'posh gray': '1', 'mirrored lavender': '4'}
# dull lavender {'light chartreuse': '3'}
# posh blue {'dim aqua': '5', 'faded crimson': '2', 'wavy yellow': '5'}
# plaid cyan {'dark green': '4', 'vibrant cyan': '2', 'clear chartreuse': '2', 'clear blue': '2'}
# muted aqua {'bright black': '3', 'striped brown': '2', 'muted brown': '4', 'drab chartreuse': '5'}
# plaid turquoise {'faded salmon': '4'}
# shiny cyan {'muted lime': '5', 'dim tomato': '1'}
# mirrored indigo {'dotted yellow': '2', 'light gray': '4'}
# dull violet {'light beige': '4'}
# plaid gray {'vibrant lavender': '3', 'light chartreuse': '3', 'vibrant black': '3'}
# dim aqua {'posh coral': '1'}
# bright purple {'dark chartreuse': '4', 'muted red': '2', 'clear yellow': '4'}
# pale olive {'dull blue': '5', 'dotted lavender': '5', 'muted white': '1', 'light maroon': '5'}
# vibrant turquoise {'shiny turquoise': '3'}
# faded magenta {'posh teal': '2', 'dark indigo': '4'}
# dark chartreuse {'posh gray': '4', 'shiny turquoise': '1', 'dotted violet': '5', 'faded olive': '5'}
# mirrored plum {'light magenta': '2', 'vibrant tan': '1', 'striped aqua': '2'}
# muted maroon {'posh teal': '1', 'posh gray': '3'}
# mirrored lavender None
# dull crimson {'shiny magenta': '5'}
# wavy gold {'wavy yellow': '5', 'mirrored coral': '2', 'pale crimson': '4', 'striped brown': '5'}
# striped purple {'dim teal': '1', 'dull lime': '3', 'bright magenta': '5', 'clear yellow': '5'}
# muted green {'clear tan': '5', 'plaid indigo': '5'}
# posh yellow {'dotted yellow': '2', 'faded salmon': '5', 'plaid indigo': '5', 'plaid lime': '5'}
# striped lavender {'faded lime': '5'}
# light maroon {'vibrant coral': '3', 'dim brown': '5'}
# dim cyan {'light chartreuse': '4'}
# posh coral {'clear crimson': '3'}
# muted gold {'clear beige': '3', 'vibrant olive': '2', 'mirrored gray': '1'}
# light teal {'muted brown': '2', 'drab purple': '5', 'wavy tomato': '2', 'dotted crimson': '4'}
# striped olive {'muted lime': '1', 'muted gray': '4'}
# clear blue {'dull lavender': '3'}
# striped indigo {'vibrant purple': '3', 'dim maroon': '2', 'pale lavender': '3'}
# striped gold {'dim teal': '3'}
# faded crimson {'muted black': '4', 'bright orange': '1'}
# drab chartreuse {'bright purple': '1', 'mirrored fuchsia': '1'}
# posh teal {'striped green': '5', 'posh purple': '3', 'wavy yellow': '1', 'clear gray': '5'}
# mirrored violet {'shiny violet': '2', 'plaid purple': '1', 'light tan': '4'}
# dim red {'vibrant crimson': '2'}
# striped blue {'dull silver': '4'}
# striped brown {'dark chartreuse': '2', 'posh turquoise': '2', 'muted red': '2', 'vibrant tomato': '1'}
# pale blue {'pale indigo': '1', 'faded cyan': '4', 'vibrant indigo': '2'}
# plaid tan {'dim tomato': '4'}
# dull chartreuse {'drab magenta': '4'}
# dim silver {'wavy indigo': '1', 'posh lavender': '5'}
# dotted gold {'shiny turquoise': '1', 'striped brown': '2', 'striped violet': '4', 'vibrant olive': '5'}
# dark beige {'vibrant tan': '2', 'bright aqua': '3'}
# plaid lavender {'vibrant violet': '2', 'dull tan': '4', 'light bronze': '2'}
# clear lime {'muted aqua': '5', 'muted black': '2', 'plaid maroon': '5', 'vibrant green': '3'}
# pale crimson {'wavy black': '3'}
# dotted purple {'wavy fuchsia': '5', 'posh lavender': '2', 'striped green': '2'}
# faded beige {'vibrant white': '1', 'light beige': '2', 'pale green': '4', 'dotted black': '4'}
# bright orange {'dim tomato': '4'}
# light lavender {'wavy white': '1', 'plaid red': '1'}
# clear beige {'posh lavender': '2', 'dim tomato': '1', 'shiny coral': '3'}
# posh silver {'light gray': '3', 'muted chartreuse': '3', 'plaid silver': '3', 'drab salmon': '1'}
# wavy aqua {'dull aqua': '1'}
# clear indigo {'pale gold': '2', 'dull cyan': '5'}
# dark green {'muted tan': '3', 'striped coral': '4'}
# wavy bronze {'faded black': '1', 'dark salmon': '3', 'bright magenta': '4', 'dark teal': '2'}
# pale cyan {'mirrored lavender': '1'}
# wavy lavender {'dotted black': '3', 'pale indigo': '4', 'clear green': '3', 'vibrant plum': '4'}
# bright black {'wavy purple': '3', 'pale cyan': '5', 'clear gray': '4', 'dull blue': '2'}
# dotted beige {'mirrored violet': '1', 'plaid black': '2'}
# clear black {'dark indigo': '4', 'light magenta': '3'}
# dotted cyan {'pale magenta': '3'}
# dark tomato {'shiny bronze': '2', 'clear bronze': '3', 'wavy purple': '4', 'pale coral': '2'}
# mirrored yellow {'dim violet': '2', 'striped tan': '3', 'dull chartreuse': '2'}
# dull cyan {'wavy purple': '5', 'mirrored turquoise': '1'}
# posh cyan {'vibrant gray': '2'}
# dim lime {'muted tomato': '5', 'posh gray': '5', 'pale green': '4', 'striped silver': '4'}
# posh salmon {'shiny green': '2', 'dotted black': '3', 'clear bronze': '2', 'muted lavender': '2'}
# shiny aqua {'muted salmon': '2', 'plaid indigo': '5', 'posh teal': '5'}
# posh aqua {'dim lime': '4', 'striped purple': '5'}
# dull turquoise {'dotted coral': '1', 'bright indigo': '4', 'shiny tan': '2'}
# light beige {'shiny gold': '5', 'clear yellow': '1', 'striped yellow': '3', 'muted salmon': '4'}
# drab purple {'clear brown': '1'}
# mirrored purple {'drab cyan': '3', 'light plum': '2'}
# plaid silver {'clear coral': '1'}
# mirrored bronze {'pale crimson': '3', 'dark brown': '2', 'vibrant tan': '1'}
# pale orange {'striped gray': '4'}
# mirrored black {'clear crimson': '2'}
# mirrored tomato {'light turquoise': '5', 'faded gold': '1'}
# posh magenta {'dotted silver': '5'}
# posh chartreuse {'dim yellow': '5'}
# dotted black {'mirrored turquoise': '3'}
# plaid indigo {'mirrored fuchsia': '3', 'wavy yellow': '5', 'plaid silver': '2', 'vibrant blue': '3'}
# drab coral {'wavy indigo': '4', 'clear salmon': '3', 'muted teal': '4'}
# plaid orange {'dotted plum': '2'}
# light orange {'light tomato': '4', 'vibrant blue': '4', 'light coral': '3'}
# striped maroon {'dark brown': '3', 'light silver': '1'}
# striped cyan {'muted orange': '4', 'light silver': '1', 'pale gold': '2', 'shiny plum': '4'}
# posh violet {'dark violet': '2', 'striped olive': '4', 'pale silver': '1'}
# striped lime {'dim orange': '4'}

# %% [markdown]
# ## Part 1

# %%
colours = list(bags.keys())

def can_hold(colour):    
    succs = bags[colour]
    if succs is None:
        return False
    elif 'shiny gold' in list(succs.keys()):
        return True
    else:
        return any([can_hold(col) for col in succs.keys()])
    
can_hold('dark orange')
valid = 0      
for col in colours:
    if not(col == 'shiny gold'):
        valid += 1 if can_hold(col) else 0

valid
# Out:
# 226

# %% [markdown]
# ## Part 2

# %%
def how_many(col):
    succs = bags[col]
    if succs is None:
        return 1
    else:
        # me plus + immediate succ
        return 1 + sum([(how_many(s)*int(succs[s])) for s in succs.keys()])

how_many('shiny gold') - 1
# Out:
# 9569
